# %% [markdown]
# # Import

# %%
import numpy as np
from scipy.interpolate import griddata
from scipy import interpolate, signal
import cPickle as pickle

# %% [markdown]
# # Observed Grid and Data

# %%
# Total field anomaly of aero survey at z=900m in Carajas, Para, Brasil
yi_f1,xi_f1,zi_f1,dobs_f1 = np.genfromtxt('1123_GravLine.XYZ', skip_header=11, usecols = (0, 1, 15, 7),
                                              invalid_raise=False, unpack=True)

# Total field anomaly of aero survey Tie lines at z=900m in Carajas, Para, Brasil
yi_f2,xi_f2,zi_f2,dobs_f2 = np.genfromtxt('1123_GravTie.XYZ', skip_header=11, usecols = (0, 1, 15, 7),
                                              invalid_raise=False, unpack=True)
# Out:
# C:\ProgramData\Anaconda2\lib\site-packages\ipykernel_launcher.py:3: ConversionWarning: Some errors were detected !
#     Line #50751 (got 2 columns instead of 4)
#     Line #94466 (got 2 columns instead of 4)
#     Line #94467 (got 2 columns instead of 4)
#     Line #94468 (got 2 columns instead of 4)
#     Line #142014 (got 2 columns instead of 4)
#     Line #186268 (got 2 columns instead of 4)
#     Line #186269 (got 2 columns instead of 4)
#     Line #186270 (got 2 columns instead of 4)
#     Line #229313 (got 2 columns instead of 4)
#     Line #277177 (got 2 columns instead of 4)
#     Line #277178 (got 2 columns instead of 4)
#     Line #277179 (got 2 columns instead of 4)
#     Line #320843 (got 2 columns instead of 4)
#     Line #368908 (got 2 columns instead of 4)
#     Line #368909 (got 2 columns instead of 4)
#     Line #368910 (got 2 columns instead of 4)
#     Line #411922 (got 2 columns instead of 4)
#     Line #458617 (got 2 columns instead of 4)
#     Line #458618 (got 2 columns instead of 4)
#     Line #458619 (got 2 columns instead of 4)
#     Line #501963 (got 2 columns instead of 4)
#     Line #549421 (got 2 columns instead of 4)
#     Line #549422 (got 2 columns instead of 4)
#     Line #549423 (got 2 columns instead of 4)
#     Line #594267 (got 2 columns instead of 4)
#     Line #641167 (got 2 columns instead of 4)
#     Line #641168 (got 2 columns instead of 4)
#     Line #641169 (got 2 columns instead of 4)
#     Line #686942 (got 2 columns instead of 4)
#     Line #732888 (got 2 columns instead of 4)
#     Line #732889 (got 2 columns instead of 4)
#     Line #732890 (got 2 columns instead of 4)
#     Line #776259 (got 2 columns instead of 4)
#     Line #821835 (got 2 columns instead of 4)
#     Line #821836 (got 2 columns instead of 4)
#     Line #821837 (got 2 columns instead of 4)
#     Line #868237 (got 2 columns instead of 4)
#     Line #868238 (got 2 columns instead of 4)
#     Line #915510 (got 2 columns instead of 4)
#     Line #915511 (got 2 columns instead of 4)
#     Line #959507 (got 2 columns instead of 4)
#     Line #959508 (got 2 columns instead of 4)
#     Line #1006660 (got 2 columns instead of 4)
#     Line #1006661 (got 2 columns instead of 4)
#     Line #1006662 (got 2 columns instead of 4)
#     Line #1052022 (got 2 columns instead of 4)
#     Line #1099851 (got 2 columns instead of 4)
#     Line #1099852 (got 2 columns instead of 4)
#     Line #1099853 (got 2 columns instead of 4)
#     Line #1144894 (got 2 columns instead of 4)
#     Line #1190932 (got 2 columns instead of 4)
#     Line #1190933 (got 2 columns instead of 4)
#     Line #1190934 (got 2 columns instead of 4)
#     Line #1234509 (got 2 columns instead of 4)
#     Line #1234510 (got 2 columns instead of 4)
#     Line #1234511 (got 2 columns instead of 4)
#     Line #1281978 (got 2 columns instead of 4)
#     Line #1281979 (got 2 columns instead of 4)
#     Line #1281980 (got 2 columns instead of 4)
#     Line #1326390 (got 2 columns instead of 4)
#     Line #1326391 (got 2 columns instead of 4)
#     Line #1326392 (got 2 columns instead of 4)
#     Line #1352947 (got 2 columns instead of 4)
#     Line #1352948 (got 2 columns instead of 4)
#     Line #1352949 (got 2 columns instead of 4)
#     Line #1372499 (got 2 columns instead of 4)
#     Line #1372500 (got 2 columns instead of 4)
#     Line #1372501 (got 2 columns instead of 4)
#     Line #1417340 (got 2 columns instead of 4)
#     Line #1417341 (got 2 columns instead of 4)
#     Line #1417342 (got 2 columns instead of 4)
#     Line #1439541 (got 2 columns instead of 4)
#     Line #1439542 (got 2 columns instead of 4)
#     Line #1439543 (got 2 columns instead of 4)
#     Line #1465820 (got 2 columns instead of 4)
#     Line #1465821 (got 2 columns instead of 4)
#     Line #1465822 (got 2 columns instead of 4)
#     Line #1509351 (got 2 columns instead of 4)
#     Line #1509352 (got 2 columns instead of 4)
#     Line #1509353 (got 2 columns instead of 4)
#     Line #1533083 (got 2 columns instead of 4)
#     Line #1553811 (got 2 columns instead of 4)
#     Line #1553812 (got 2 columns instead of 4)
#     Line #1553813 (got 2 columns instead of 4)
#     Line #1597669 (got 2 columns instead of 4)
#     Line #1597670 (got 2 columns instead of 4)
#     Line #1597671 (got 2 columns instead of 4)
#     Line #1621035 (got 2 columns instead of 4)
#     Line #1621036 (got 2 columns instead of 4)
#     Line #1621037 (got 2 columns instead of 4)
#     Line #1644457 (got 2 columns instead of 4)
#     Line #1644458 (got 2 columns instead of 4)
#     Line #1644459 (got 2 columns instead of 4)
#     Line #1687706 (got 2 columns instead of 4)
#     Line #1687707 (got 2 columns instead of 4)
#     Line #1687708 (got 2 columns instead of 4)
#     Line #1713349 (got 2 columns instead of 4)
#     Line #1733468 (got 2 columns instead of 4)
#     Line #1733469 (got 2 columns instead of 4)
#     Line #1733470 (got 2 columns instead of 4)
#     Line #1775493 (got 2 columns instead of 4)
#     Line #1775494 (got 2 columns instead of 4)
#     Line #1775495 (got 2 columns instead of 4)
#     Line #1802096 (got 2 columns instead of 4)
#     Line #1802097 (got 2 columns instead of 4)
#     Line #1802098 (got 2 columns instead of 4)
#     Line #1821524 (got 2 columns instead of 4)
#     Line #1821525 (got 2 columns instead of 4)
#     Line #1821526 (got 2 columns instead of 4)
#     Line #1863261 (got 2 columns instead of 4)
#     Line #1863262 (got 2 columns instead of 4)
#     Line #1863263 (got 2 columns instead of 4)
#     Line #1888870 (got 2 columns instead of 4)
#     Line #1908503 (got 2 columns instead of 4)
#     Line #1952832 (got 2 columns instead of 4)
#     Line #1952833 (got 2 columns instead of 4)
#     Line #1952834 (got 2 columns instead of 4)
#     Line #1980017 (got 2 columns instead of 4)
#     Line #2000058 (got 2 columns instead of 4)
#     Line #2042335 (got 2 columns instead of 4)
#     Line #2042336 (got 2 columns instead of 4)
#     Line #2042337 (got 2 columns instead of 4)
#     Line #2068673 (got 2 columns instead of 4)
#     Line #2088881 (got 2 columns instead of 4)
#     Line #2132572 (got 2 columns instead of 4)
#     Line #2132573 (got 2 columns instead of 4)
#     Line #2132574 (got 2 columns instead of 4)
#     Line #2160111 (got 2 columns instead of 4)
#     Line #2180913 (got 2 columns instead of 4)
#     Line #2224423 (got 2 columns instead of 4)
#     Line #2224424 (got 2 columns instead of 4)
#     Line #2224425 (got 2 columns instead of 4)
#     Line #2270876 (got 2 columns instead of 4)
#     Line #2315155 (got 2 columns instead of 4)
#     Line #2315156 (got 2 columns instead of 4)
#     Line #2315157 (got 2 columns instead of 4)
#     Line #2362145 (got 2 columns instead of 4)
#     Line #2407344 (got 2 columns instead of 4)
#     Line #2407345 (got 2 columns instead of 4)
#     Line #2407346 (got 2 columns instead of 4)
#     Line #2416980 (got 2 columns instead of 4)
#     Line #2416981 (got 2 columns instead of 4)
#     Line #2416982 (got 2 columns instead of 4)
#     Line #2456329 (got 2 columns instead of 4)
#     Line #2456330 (got 2 columns instead of 4)
#     Line #2456331 (got 2 columns instead of 4)
#     Line #2501311 (got 2 columns instead of 4)
#     Line #2501312 (got 2 columns instead of 4)
#     Line #2501313 (got 2 columns instead of 4)
#     Line #2514952 (got 2 columns instead of 4)
#     Line #2514953 (got 2 columns instead of 4)
#     Line #2514954 (got 2 columns instead of 4)
#     Line #2546477 (got 2 columns instead of 4)
#     Line #2546478 (got 2 columns instead of 4)
#     Line #2546479 (got 2 columns instead of 4)
#     Line #2592644 (got 2 columns instead of 4)
#     Line #2592645 (got 2 columns instead of 4)
#     Line #2636745 (got 2 columns instead of 4)
#     Line #2636746 (got 2 columns instead of 4)
#     Line #2636747 (got 2 columns instead of 4)
#     Line #2684586 (got 2 columns instead of 4)
#     Line #2684587 (got 2 columns instead of 4)
#     Line #2684588 (got 2 columns instead of 4)
#     Line #2708099 (got 2 columns instead of 4)
#     Line #2708100 (got 2 columns instead of 4)
#     Line #2708101 (got 2 columns instead of 4)
#     Line #2731308 (got 2 columns instead of 4)
#     Line #2754516 (got 2 columns instead of 4)
#     Line #2754517 (got 2 columns instead of 4)
#     Line #2754518 (got 2 columns instead of 4)
#     Line #2777634 (got 2 columns instead of 4)
#     Line #2777635 (got 2 columns instead of 4)
#     Line #2777636 (got 2 columns instead of 4)
#     Line #2800807 (got 2 columns instead of 4)
#     Line #2800808 (got 2 columns instead of 4)
#     Line #2800809 (got 2 columns instead of 4)
#     Line #2823962 (got 2 columns instead of 4)
#     Line #2823963 (got 2 columns instead of 4)
#     Line #2823964 (got 2 columns instead of 4)
#     Line #2847140 (got 2 columns instead of 4)
#     Line #2870480 (got 2 columns instead of 4)
#     Line #2870481 (got 2 columns instead of 4)
#     Line #2870482 (got 2 columns instead of 4)
#     Line #2893971 (got 2 columns instead of 4)
#     Line #2893972 (got 2 columns instead of 4)
#     Line #2893973 (got 2 columns instead of 4)
#     Line #2917358 (got 2 columns instead of 4)
#     Line #2940740 (got 2 columns instead of 4)
#     Line #2940741 (got 2 columns instead of 4)
#     Line #2940742 (got 2 columns instead of 4)
#     Line #2964068 (got 2 columns instead of 4)
#     Line #2987388 (got 2 columns instead of 4)
#     Line #2987389 (got 2 columns instead of 4)
#     Line #2987390 (got 2 columns instead of 4)
#     Line #3010613 (got 2 columns instead of 4)
#     Line #3033892 (got 2 columns instead of 4)
#     Line #3033893 (got 2 columns instead of 4)
#     Line #3033894 (got 2 columns instead of 4)
#     Line #3057135 (got 2 columns instead of 4)
#     Line #3080358 (got 2 columns instead of 4)
#     Line #3080359 (got 2 columns instead of 4)
#     Line #3080360 (got 2 columns instead of 4)
#     Line #3102997 (got 2 columns instead of 4)
#     Line #3125799 (got 2 columns instead of 4)
#     Line #3125800 (got 2 columns instead of 4)
#     Line #3125801 (got 2 columns instead of 4)
#     Line #3148455 (got 2 columns instead of 4)
#     Line #3171465 (got 2 columns instead of 4)
#     Line #3171466 (got 2 columns instead of 4)
#     Line #3171467 (got 2 columns instead of 4)
#     Line #3194202 (got 2 columns instead of 4)
#     Line #3217099 (got 2 columns instead of 4)
#     Line #3217100 (got 2 columns instead of 4)
#     Line #3217101 (got 2 columns instead of 4)
#     Line #3239634 (got 2 columns instead of 4)
#     Line #3262485 (got 2 columns instead of 4)
#     Line #3262486 (got 2 columns instead of 4)
#     Line #3262487 (got 2 columns instead of 4)
#     Line #3285796 (got 2 columns instead of 4)
#     Line #3308882 (got 2 columns instead of 4)
#     Line #3308883 (got 2 columns instead of 4)
#     Line #3308884 (got 2 columns instead of 4)
#     Line #3332208 (got 2 columns instead of 4)
#     Line #3332209 (got 2 columns instead of 4)
#     Line #3332210 (got 2 columns instead of 4)
#     Line #3355338 (got 2 columns instead of 4)
#     Line #3355339 (got 2 columns instead of 4)
#     Line #3355340 (got 2 columns instead of 4)
#     Line #3378848 (got 2 columns instead of 4)
#     Line #3401987 (got 2 columns instead of 4)
#     Line #3401988 (got 2 columns instead of 4)
#     Line #3401989 (got 2 columns instead of 4)
#     Line #3425249 (got 2 columns instead of 4)
#     Line #3448391 (got 2 columns instead of 4)
#     Line #3448392 (got 2 columns instead of 4)
#     Line #3448393 (got 2 columns instead of 4)
#     Line #3471509 (got 2 columns instead of 4)
#     Line #3494750 (got 2 columns instead of 4)
#     Line #3494751 (got 2 columns instead of 4)
#     Line #3494752 (got 2 columns instead of 4)
#     Line #3517680 (got 2 columns instead of 4)
#     Line #3541030 (got 2 columns instead of 4)
#     Line #3541031 (got 2 columns instead of 4)
#     Line #3541032 (got 2 columns instead of 4)
#     Line #3564358 (got 2 columns instead of 4)
#     Line #3572248 (got 2 columns instead of 4)
#     Line #3572249 (got 2 columns instead of 4)
#     Line #3572250 (got 2 columns instead of 4)
#     Line #3587885 (got 2 columns instead of 4)
#     Line #3587886 (got 2 columns instead of 4)
#     Line #3587887 (got 2 columns instead of 4)
#     Line #3611360 (got 2 columns instead of 4)
#     Line #3634888 (got 2 columns instead of 4)
#     Line #3634889 (got 2 columns instead of 4)
#     Line #3634890 (got 2 columns instead of 4)
#     Line #3657507 (got 2 columns instead of 4)
#     Line #3657508 (got 2 columns instead of 4)
#     Line #3657509 (got 2 columns instead of 4)
#     Line #3680618 (got 2 columns instead of 4)
#     Line #3703299 (got 2 columns instead of 4)
#     Line #3703300 (got 2 columns instead of 4)
#     Line #3703301 (got 2 columns instead of 4)
#     Line #3726118 (got 2 columns instead of 4)
#     Line #3749477 (got 2 columns instead of 4)
#     Line #3749478 (got 2 columns instead of 4)
#     Line #3749479 (got 2 columns instead of 4)
#     Line #3772407 (got 2 columns instead of 4)
#     Line #3795468 (got 2 columns instead of 4)
#     Line #3795469 (got 2 columns instead of 4)
#     Line #3795470 (got 2 columns instead of 4)
#     Line #3818306 (got 2 columns instead of 4)
#     Line #3841184 (got 2 columns instead of 4)
#     Line #3841185 (got 2 columns instead of 4)
#     Line #3841186 (got 2 columns instead of 4)
#     Line #3864651 (got 2 columns instead of 4)
#     Line #3887769 (got 2 columns instead of 4)
#     Line #3887770 (got 2 columns instead of 4)
#     Line #3887771 (got 2 columns instead of 4)
#     Line #3900339 (got 2 columns instead of 4)
#     Line #3900340 (got 2 columns instead of 4)
#     Line #3900341 (got 2 columns instead of 4)
#     Line #3911037 (got 2 columns instead of 4)
#     Line #3911038 (got 2 columns instead of 4)
#     Line #3911039 (got 2 columns instead of 4)
#     Line #3923605 (got 2 columns instead of 4)
#     Line #3923606 (got 2 columns instead of 4)
#     Line #3923607 (got 2 columns instead of 4)
#     Line #3933970 (got 2 columns instead of 4)
#     Line #3933971 (got 2 columns instead of 4)
#     Line #3933972 (got 2 columns instead of 4)
#     Line #3943932 (got 2 columns instead of 4)
#     Line #3943933 (got 2 columns instead of 4)
#     Line #3943934 (got 2 columns instead of 4)
#     Line #3957080 (got 2 columns instead of 4)
#     Line #3957081 (got 2 columns instead of 4)
#     Line #3957082 (got 2 columns instead of 4)
#     Line #3967320 (got 2 columns instead of 4)
#     Line #3967321 (got 2 columns instead of 4)
#     Line #3967322 (got 2 columns instead of 4)
#     Line #3980214 (got 2 columns instead of 4)
#     Line #3980215 (got 2 columns instead of 4)
#     Line #3980216 (got 2 columns instead of 4)
#     Line #4002860 (got 2 columns instead of 4)
#     Line #4002861 (got 2 columns instead of 4)
#     Line #4002862 (got 2 columns instead of 4)
#     Line #4026090 (got 2 columns instead of 4)
#     Line #4026091 (got 2 columns instead of 4)
#     Line #4026092 (got 2 columns instead of 4)
#     Line #4049757 (got 2 columns instead of 4)
#     Line #4064110 (got 2 columns instead of 4)
#     Line #4064111 (got 2 columns instead of 4)
#     Line #4064112 (got 2 columns instead of 4)
#     Line #4073582 (got 2 columns instead of 4)
#     Line #4073583 (got 2 columns instead of 4)
#     Line #4073584 (got 2 columns instead of 4)
#     Line #4096924 (got 2 columns instead of 4)
#     Line #4120314 (got 2 columns instead of 4)
#     Line #4120315 (got 2 columns instead of 4)
#     Line #4120316 (got 2 columns instead of 4)
#     Line #4143522 (got 2 columns instead of 4)
#     Line #4159176 (got 2 columns instead of 4)
#     Line #4159177 (got 2 columns instead of 4)
#     Line #4159178 (got 2 columns instead of 4)
#     Line #4167143 (got 2 columns instead of 4)
#     Line #4167144 (got 2 columns instead of 4)
#     Line #4167145 (got 2 columns instead of 4)
#     Line #4186890 (got 2 columns instead of 4)
#     Line #4186891 (got 2 columns instead of 4)
#     Line #4186892 (got 2 columns instead of 4)
#     Line #4190516 (got 2 columns instead of 4)
#     Line #4190517 (got 2 columns instead of 4)
#     Line #4190518 (got 2 columns instead of 4)
#     Line #4213860 (got 2 columns instead of 4)
#     Line #4213861 (got 2 columns instead of 4)
#     Line #4213862 (got 2 columns instead of 4)
#     Line #4237041 (got 2 columns instead of 4)
#     Line #4260208 (got 2 columns instead of 4)
#     Line #4260209 (got 2 columns instead of 4)
#     Line #4260210 (got 2 columns instead of 4)
#     Line #4283498 (got 2 columns instead of 4)
#     Line #4307057 (got 2 columns instead of 4)
#     Line #4307058 (got 2 columns instead of 4)
#     Line #4307059 (got 2 columns instead of 4)
#     Line #4313267 (got 2 columns instead of 4)
#     Line #4313268 (got 2 columns instead of 4)
#     Line #4313269 (got 2 columns instead of 4)
#     Line #4330180 (got 2 columns instead of 4)
#     Line #4330181 (got 2 columns instead of 4)
#     Line #4330182 (got 2 columns instead of 4)
#   This is separate from the ipykernel package so we can avoid doing imports until
# C:\ProgramData\Anaconda2\lib\site-packages\ipykernel_launcher.py:7: ConversionWarning: Some errors were detected !
#     Line #23086 (got 2 columns instead of 4)
#     Line #49210 (got 2 columns instead of 4)
#     Line #72428 (got 2 columns instead of 4)
#     Line #97714 (got 2 columns instead of 4)
#     Line #97715 (got 2 columns instead of 4)
#     Line #97716 (got 2 columns instead of 4)
#     Line #120678 (got 2 columns instead of 4)
#     Line #143951 (got 2 columns instead of 4)
#     Line #143952 (got 2 columns instead of 4)
#     Line #143953 (got 2 columns instead of 4)
#     Line #168971 (got 2 columns instead of 4)
#     Line #192825 (got 2 columns instead of 4)
#     Line #192826 (got 2 columns instead of 4)
#     Line #192827 (got 2 columns instead of 4)
#     Line #217957 (got 2 columns instead of 4)
#     Line #217958 (got 2 columns instead of 4)
#     Line #217959 (got 2 columns instead of 4)
#     Line #240176 (got 2 columns instead of 4)
#     Line #263659 (got 2 columns instead of 4)
#     Line #286859 (got 2 columns instead of 4)
#     Line #310493 (got 2 columns instead of 4)
#     Line #310494 (got 2 columns instead of 4)
#     Line #310495 (got 2 columns instead of 4)
#     Line #332151 (got 2 columns instead of 4)
#     Line #332152 (got 2 columns instead of 4)
#     Line #332153 (got 2 columns instead of 4)
#     Line #357471 (got 2 columns instead of 4)
#     Line #383304 (got 2 columns instead of 4)
#     Line #383305 (got 2 columns instead of 4)
#     Line #383306 (got 2 columns instead of 4)
#     Line #408356 (got 2 columns instead of 4)
#     Line #425448 (got 2 columns instead of 4)
#     Line #425449 (got 2 columns instead of 4)
#     Line #425450 (got 2 columns instead of 4)
#     Line #432944 (got 2 columns instead of 4)
#     Line #432945 (got 2 columns instead of 4)
#     Line #432946 (got 2 columns instead of 4)
#     Line #458064 (got 2 columns instead of 4)
#     Line #482484 (got 2 columns instead of 4)
#     Line #482485 (got 2 columns instead of 4)
#     Line #482486 (got 2 columns instead of 4)
#     Line #507123 (got 2 columns instead of 4)
#     Line #531710 (got 2 columns instead of 4)
#     Line #531711 (got 2 columns instead of 4)
#     Line #531712 (got 2 columns instead of 4)
#     Line #556403 (got 2 columns instead of 4)
#     Line #580990 (got 2 columns instead of 4)
#     Line #580991 (got 2 columns instead of 4)
#     Line #580992 (got 2 columns instead of 4)
#     Line #605807 (got 2 columns instead of 4)
#     Line #605808 (got 2 columns instead of 4)
#     Line #605809 (got 2 columns instead of 4)
#     Line #621826 (got 2 columns instead of 4)
#     Line #621827 (got 2 columns instead of 4)
#     Line #621828 (got 2 columns instead of 4)
#     Line #630475 (got 2 columns instead of 4)
#     Line #630476 (got 2 columns instead of 4)
#     Line #630477 (got 2 columns instead of 4)
#     Line #655743 (got 2 columns instead of 4)
#     Line #655744 (got 2 columns instead of 4)
#     Line #655745 (got 2 columns instead of 4)
#     Line #680111 (got 2 columns instead of 4)
#     Line #705718 (got 2 columns instead of 4)
#     Line #705719 (got 2 columns instead of 4)
#     Line #705720 (got 2 columns instead of 4)
#     Line #720858 (got 2 columns instead of 4)
#     Line #720859 (got 2 columns instead of 4)
#     Line #720860 (got 2 columns instead of 4)
#     Line #735780 (got 2 columns instead of 4)
#     Line #750511 (got 2 columns instead of 4)
#     Line #750512 (got 2 columns instead of 4)
#     Line #750513 (got 2 columns instead of 4)
#     Line #765943 (got 2 columns instead of 4)
#     Line #780772 (got 2 columns instead of 4)
#     Line #780773 (got 2 columns instead of 4)
#     Line #780774 (got 2 columns instead of 4)
#     Line #795822 (got 2 columns instead of 4)
#     Line #810996 (got 2 columns instead of 4)
#     Line #810997 (got 2 columns instead of 4)
#     Line #810998 (got 2 columns instead of 4)
#     Line #825703 (got 2 columns instead of 4)
#     Line #840427 (got 2 columns instead of 4)
#     Line #840428 (got 2 columns instead of 4)
#     Line #840429 (got 2 columns instead of 4)
#     Line #855741 (got 2 columns instead of 4)
#     Line #870664 (got 2 columns instead of 4)
#     Line #870665 (got 2 columns instead of 4)
#     Line #870666 (got 2 columns instead of 4)
#     Line #885304 (got 2 columns instead of 4)
#     Line #900507 (got 2 columns instead of 4)
#     Line #900508 (got 2 columns instead of 4)
#     Line #900509 (got 2 columns instead of 4)
#     Line #915295 (got 2 columns instead of 4)
#     Line #930191 (got 2 columns instead of 4)
#     Line #930192 (got 2 columns instead of 4)
#     Line #930193 (got 2 columns instead of 4)
#     Line #945035 (got 2 columns instead of 4)
#     Line #959891 (got 2 columns instead of 4)
#     Line #959892 (got 2 columns instead of 4)
#     Line #959893 (got 2 columns instead of 4)
#     Line #974790 (got 2 columns instead of 4)
#     Line #989623 (got 2 columns instead of 4)
#     Line #989624 (got 2 columns instead of 4)
#     Line #989625 (got 2 columns instead of 4)
#     Line #1004548 (got 2 columns instead of 4)
#     Line #1019598 (got 2 columns instead of 4)
#     Line #1019599 (got 2 columns instead of 4)
#     Line #1019600 (got 2 columns instead of 4)
#     Line #1034364 (got 2 columns instead of 4)
#     Line #1049894 (got 2 columns instead of 4)
#     Line #1049895 (got 2 columns instead of 4)
#     Line #1049896 (got 2 columns instead of 4)
#     Line #1064765 (got 2 columns instead of 4)
#     Line #1079876 (got 2 columns instead of 4)
#     Line #1079877 (got 2 columns instead of 4)
#     Line #1079878 (got 2 columns instead of 4)
#     Line #1094693 (got 2 columns instead of 4)
#     Line #1109729 (got 2 columns instead of 4)
#     Line #1109730 (got 2 columns instead of 4)
#     Line #1109731 (got 2 columns instead of 4)
#     Line #1124435 (got 2 columns instead of 4)
#   import sys

# %%
xi_c = np.hstack((xi_f1,xi_f2))
yi_c = np.hstack((yi_f1,yi_f2))
zi_c = np.hstack((zi_f1,zi_f2))
dobs_c = np.hstack((dobs_f1,dobs_f2))
dobs_c.shape
# Out:
# (5492551L,)

# %% [markdown]
# # Create a regular grid using the observation data

# %%
# Create a regular grid
shape_m = (500, 500)
grid_x = np.linspace(np.min(xi_c),np.max(xi_c),shape_m[0])
grid_y = np.linspace(np.min(yi_c),np.max(yi_c),shape_m[1])
grid_y, grid_x = np.meshgrid(grid_y, grid_x)
grid_z = np.zeros_like(grid_x)-900
grid_dobs = griddata((xi_c,yi_c), dobs_c, (grid_x, grid_y), method='nearest')

# %%
carajas = dict()
carajas['x'] = np.ravel(grid_x)
carajas['y'] = np.ravel(grid_y)
carajas['z'] = np.ravel(grid_z)
carajas['gz'] = np.ravel(grid_dobs)

# %%
#save the data
file_name = 'carajas_gz.pickle'
with open(file_name, 'w') as f:
    pickle.dump(carajas, f)

# %% [markdown]
# # Test pickle file

# %%
with open('carajas_gz.pickle') as r:
    carajas_test = pickle.load(r)

# %%
carajas_test['x']
# Out:
# array([9102750.7, 9102750.7, 9102750.7, ..., 9460499.3, 9460499.3,
#        9460499.3])

# %%
carajas_test['y']
# Out:
# array([275977.47      , 276765.08971944, 277552.70943888, ...,
#        667424.47056112, 668212.09028056, 668999.71      ])
